# %% [markdown]
# # CLASE 1
# ### **FUNDAMENTOS DE LÓGICA Y CONJUNTOS: LA BASE DE LAS MATEMÁTICAS Y LA PROGRAMACIÓN**
#
# ✦
# **Introducción** a un nuevo curso que busca cambiar la forma en que se enseña matemáticas, centrándose en comprender las matemáticas como objeto de estudio en sí mismo.
#
# *   El curso fue planeado por tres profesores: Wilson Pérez, Francisco Pérez y el hablante.
# *   Se busca ir más allá de las matemáticas como herramienta, enfocándose en comprender los objetos matemáticos.
# *   La primera parte del curso va desde hoy hasta el 11 de julio, luego se concentrarán en temas más avanzados en agosto.
#
# ## Lógica Proposicional
#
# ✦
# Se **explica** cómo se forman las tablas de verdad para proposiciones y la importancia de automatizar el proceso.
#
# *   Las tablas de verdad se forman con 2 a la k posibilidades, donde k es el número de proposiciones.
# *   Con una proposición, hay 2 posibles valores de verdad.
# *   Con dos proposiciones, se tienen 4 posibles combinaciones en la tabla de verdad.
# *   Se menciona la importancia de utilizar programas informáticos para sistematizar y automatizar este proceso.
#
# ✦
# Operadores Lógicos
#
# Los operadores lógicos principales son:
#
# *   Negación (¬)
# *   Conjunción (∧)
# *   Disyunción (∨)
# *   Implicación (→)
# *   Doble implicación (↔)
#
# <img src="/content/0c4409de56c895f5c200fcf5e6517754.jpg" alt="Tablas de verdad">
#
# ## Ejemplos de lógica proposicional
#
# ### Proposiciones simples y compuestas:
#
# *   Proposición simple:
# 𝑝("Hoy es lunes")
#
# *   Proposición compuesta:
# 𝑝
# ∧
# 𝑞
#  ("Hoy es lunes y está lloviendo")
#
# ### Conectores lógicos:
#
# *   Conjunción (
# ∧):
# 𝑝∧𝑞("Hoy es lunes y está lloviendo")
#
# *   Disyunción (∨):
# 𝑝∨𝑞("Hoy es lunes o está lloviendo")
#
# *   Negación (¬):
# ¬𝑝("No es lunes")
#
# *   Condicional (→):
# 𝑝→𝑞("Si hoy es lunes, entonces está lloviendo")
#
# *   Bicondicional (↔):
# 𝑝↔𝑞("Hoy es lunes si y solo si está lloviendo")
#
# ### Aplicaciones de la lógica proposicional
#
# *   Matemáticas y Lógica Formal:
#
# Utilizada para probar teoremas y validar argumentos.
#
# Base para sistemas más complejos como la lógica de primer orden.
#
# *   Ciencias de la Computación:
#
# Verificación de software: Para asegurar que los programas cumplen con ciertas especificaciones.
#
# Inteligencia artificial: En la resolución de problemas y la toma de decisiones basada en reglas.
#
# Sistemas expertos: Para modelar el conocimiento y las reglas de inferencia.
#
# *   Circuitos Digitales:
#
# Diseño y análisis de circuitos lógicos y digitales.
#
# Uso en la simplificación de circuitos a través de álgebra booleana.
#
# *   Sistemas de Información:
#
# Bases de datos: Para formular consultas lógicas.
#
# Lenguajes de consulta: Como SQL, que usan lógica proposicional para recuperar datos.
#
# *   Lingüística:
#
# Análisis de la estructura lógica del lenguaje natural.
#
# Comprensión y generación de oraciones complejas basadas en reglas gramaticales y lógicas.
#
# *   Filosofía:
#
# Análisis de argumentos filosóficos y estructura lógica de los mismos.
#
# Evaluación de la validez y solidez de los argumentos.
#
# *   Automatización y Robótica:
#
# Control y toma de decisiones en sistemas automáticos.
#
# Programación de comportamientos en robots basados en reglas lógicas.
#
#
# ✦
# **Explicación** sobre la implicación lógica y la equivalencia en proposiciones.
#
# *   La implicación es verdadera excepto cuando la primera proposición es verdadera y la segunda es falsa.
# *   La equivalencia entre p y q es verdadera si ambas son iguales, es decir, p y q o no q y no p.
# *   Se muestra con ejemplos de interruptores de luz para comprender mejor estos conceptos lógicos.
#
# ✦
# Se **explica** la importancia de la orden de los cuantificadores en la lógica.
#
# *   La posición de los cuantificadores altera el resultado en una proposición.
# *   Se ejemplifica la diferencia entre "para todo niño, hay una madre" y "existe una madre para todo niño".
# *   Se invita a los participantes a conectarse a través de un código QR para una actividad interactiva.
#
#
# ## Teoría de Conjuntos
#
# ✦
# **Explicación** sobre conjuntos y elementos en matemáticas.
# Los objetos que pertenecen a un conjunto se llaman elementos.
#
# *   Para denotar un conjunto se utilizan letras mayúsculas, como A o B.
# *   Para denotar los elementos se utilizan letras minúsculas.
# *   Se puede indicar que un elemento no pertenece a un conjunto con una línea cruzada.
#
# ✦
# Se discute la **generalización** de operaciones de conjuntos utilizando letras adicionales para evitar limitaciones notacionales.
#
# *   Se propone utilizar letras adicionales como a, b, c, d, etc., como subconjuntos de Omega para generalizar operaciones de conjuntos.
# *   Se menciona la importancia de la eficiencia en el lenguaje matemático para ahorrar tiempo y espacio.
# *   Se muestra cómo hacer más compacta la notación al describir una familia de subconjuntos de manera más concisa.
#
#
# ✦
# **Explicación** sobre la intersección de conjuntos y su representación gráfica.
#
# *   Se menciona la falta de concreción y eficiencia matemática al definir la intersección de una familia de conjuntos.
# *   Se propone utilizar subíndices o una variable que recorra todos los elementos de la familia para expresar la intersección de manera más general.
# *   Se compara esta notación con la utilizada en estadística para la suma de una familia de elementos.
# *   Se describe gráficamente cómo se realiza la intersección de conjuntos, mostrando que son los elementos comunes entre ellos.
#
# ✦
# **Explicación** sobre la definición de la intersección y unión de conjuntos infinitos.
#
# *   Se menciona la modificación en la notación para representar la intersección de una familia infinita de conjuntos.
# *   Se destaca la ambigüedad de representar el infinito como un número.
# *   Se explica la definición de la unión de una familia infinita de conjuntos, indicando que al menos un elemento pertenece al conjunto Omega.
#
# <img src="/content/conjuntos.jpg" alt="Conjuntos">
#
# ### Ejemplos de conceptos básicos en teoría de conjuntos:
#
# *   Conjuntos finitos e infinitos:
# Un conjunto finito tiene un número limitado de elementos, como el conjunto {1, 2, 3}. Un conjunto infinito, como el conjunto de los números naturales {1, 2, 3, ...}, no tiene un límite en la cantidad de elementos.
#
# *   Subconjuntos: Si todos los elementos de un conjunto A también están en un conjunto B, entonces A es un subconjunto de B. Por ejemplo, {1, 2} es un subconjunto de {1, 2, 3}.
#
# *   Unión e intersección: La unión de dos conjuntos A y B es un conjunto que contiene todos los elementos de A y B. La intersección de A y B contiene solo los elementos que están en ambos conjuntos. Por ejemplo, si A = {1, 2} y B = {2, 3}, entonces la unión de A y B es {1, 2, 3} y la intersección es {2}.
#
# *   Diferencia de conjuntos: La diferencia entre dos conjuntos A y B, denotada como A \ B, es el conjunto de elementos que están en A pero no en B. Por ejemplo, si A = {1, 2, 3} y B = {2, 3, 4}, entonces A \ B es {1}.
#
# ### Aplicaciones de la teoría de conjuntos:
# *   Matemáticas: La teoría de conjuntos es la base de muchas ramas de las matemáticas modernas. Se utiliza para definir la estructura de los números, funciones, espacios topológicos, entre otros.
#
# *   Lógica y filosofía: En lógica matemática, la teoría de conjuntos se usa para estudiar propiedades y relaciones fundamentales entre conjuntos, y para formalizar conceptos como la cardinalidad y la ordenación.
#
# *   Computación: En ciencias de la computación, los conjuntos se utilizan para modelar estructuras de datos, diseñar algoritmos, y en la teoría de bases de datos para manejar consultas y operaciones sobre datos.
#
# *   Teoría de bases de datos: Los conceptos de conjuntos se utilizan para definir las operaciones básicas en bases de datos relacionales, como la unión, intersección y diferencia de tablas.
#
# *   Teoría de grafos: Los conjuntos se utilizan para definir grafos, donde los vértices y las aristas pueden ser vistos como conjuntos. Esto es fundamental en el análisis de redes y estructuras conectadas.
#
# *   Economía: En teoría de juegos y economía, los conjuntos se utilizan para modelar preferencias, elecciones y estrategias de los agentes económicos.
#
# *   Teoría de la probabilidad: La teoría de conjuntos es esencial para definir espacios de probabilidad y eventos, lo cual es fundamental en el análisis de procesos estocásticos y teoría de la probabilidad.

# %%
# Instalar las bibliotecas necesarias
# !pip install sympy pandas matplotlib

# Importar las bibliotecas
import sympy as sp
import pandas as pd
import matplotlib.pyplot as plt

# Definir las proposiciones
P, Q = sp.symbols('P Q')

# Ejemplo 1: Negación
# ¬P
negacion_P = ~P
print(f"Negación de P (¬P): {negacion_P}")

# Ejemplo 2: Conjunción
# P ∧ Q
conjuncion = P & Q
print(f"Conjunción de P y Q (P ∧ Q): {conjuncion}")

# Ejemplo 3: Disyunción
# P ∨ Q
disyuncion = P | Q
print(f"Disyunción de P y Q (P ∨ Q): {disyuncion}")

# Ejemplo 4: Implicación
# P → Q
implicacion = sp.Implies(P, Q)
print(f"Implicación de P a Q (P → Q): {implicacion}")

# Ejemplo 5: Bicondicional
# P ↔ Q
bicondicional = sp.Equivalent(P, Q)
print(f"Bicondicional de P y Q (P ↔ Q): {bicondicional}")

# Función para generar tabla de verdad
def generar_tabla_verdad(expr):
    # Valores posibles para P y Q
    valores = [(True, True), (True, False), (False, True), (False, False)]
    filas = []

    # Calcular el resultado de la expresión para cada combinación de valores de P y Q
    for val in valores:
        P_val, Q_val = val
        resultado = expr.subs({P: P_val, Q: Q_val})
        filas.append({'P': P_val, 'Q': Q_val, 'Resultado': resultado})

    # Crear un DataFrame de pandas para la tabla de verdad
    tabla = pd.DataFrame(filas)
    return tabla

# Generar y mostrar las tablas de verdad para cada operación
expresiones = {
    "¬P": negacion_P,
    "P ∧ Q": conjuncion,
    "P ∨ Q": disyuncion,
    "P → Q": implicacion,
    "P ↔ Q": bicondicional
}

for descripcion, expr in expresiones.items():
    print(f"\nTabla de verdad para {descripcion}:")
    tabla_verdad = generar_tabla_verdad(expr)
    print(tabla_verdad)

    # Visualización de la tabla de verdad
    fig, ax = plt.subplots()
    ax.axis('tight')
    ax.axis('off')
    ax.table(cellText=tabla_verdad.values, colLabels=tabla_verdad.columns, cellLoc='center', loc='center')
    plt.title(f"Tabla de Verdad: {descripcion}")
    plt.show()

## Teoría de conjuntos ##

    # Ejemplo de conjuntos finitos e infinitos
conjunto_finito = {1, 2, 3}
# Conjunto infinito (teórico, no puede representarse completamente)
conjunto_infinito = set(range(1, 1000))  # Usamos un rango grande para simular un conjunto infinito

print("Conjunto finito:", conjunto_finito)
print("Conjunto 'infinito' (simulado):", conjunto_infinito)

# Ejemplo de subconjuntos
A = {1, 2}
B = {1, 2, 3}
es_subconjunto = A.issubset(B)

print("A es subconjunto de B:", es_subconjunto)

# Ejemplo de unión e intersección
A = {1, 2}
B = {2, 3}
print("A = ",A)
print("B = ",B)
union = A.union(B)
interseccion = A.intersection(B)

print("Unión de A y B:", union)
print("Intersección de A y B:", interseccion)

# Ejemplo de diferencia de conjuntos
A = {1, 2, 3}
B = {2, 3, 4}
diferencia = A.difference(B)

print("Diferencia de A y B (A \\ B):", diferencia)
# Out:
# ...
# Negación de P (¬P): ~P
# Conjunción de P y Q (P ∧ Q): P & Q
# Disyunción de P y Q (P ∨ Q): P | Q
# Implicación de P a Q (P → Q): Implies(P, Q)
# Bicondicional de P y Q (P ↔ Q): Equivalent(P, Q)
#
# Tabla de verdad para ¬P:
#        P      Q Resultado
# 0   True   True     False
# 1   True  False     False
# 2  False   True      True
# 3  False  False      True
# Tabla de verdad para P ∧ Q:
#        P      Q Resultado
# 0   True   True      True
# 1   True  False     False
# 2  False   True     False
# 3  False  False     False
# Tabla de verdad para P ∨ Q:
#        P      Q Resultado
# 0   True   True      True
# 1   True  False      True
# 2  False   True      True
# 3  False  False     False
# Tabla de verdad para P → Q:
#        P      Q Resultado
# 0   True   True      True
# 1   True  False     False
# 2  False   True      True
# 3  False  False      True
# Tabla de verdad para P ↔ Q:
#        P      Q Resultado
# 0   True   True      True
# 1   True  False     False
# ...
